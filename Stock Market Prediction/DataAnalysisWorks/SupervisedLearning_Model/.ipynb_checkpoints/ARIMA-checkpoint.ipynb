# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings

warnings.filterwarnings('ignore')

# %%
# Loading Data
data = pd.read_csv('D:\Master_Folder\Data Science Course\Projects\StockMarket\stock_data\SUZLON.NS_2023-01-01_to_2024-11-21_ML.csv')
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(15, 5))
plt.plot(data.index, data['Close'], label='Close Price', color = 'orange')
plt.title('Stock close price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Performing classical seasonal decomposition
decompose_addictive = seasonal_decompose(data['Close'], model='additive', period=30)

trend_addictive = decompose_addictive.trend 
seasonal_addictive = decompose_addictive.seasonal 
residual_addictive = decompose_addictive.resid 

plt.figure(figsize=(15, 10))
plt.subplot(411)
plt.plot(data['Close'], label='Original')
plt.legend(loc='upper left')
plt.subplot(412)
plt.plot(trend_addictive, label='trend_addictive')
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(seasonal_addictive, label='seasonal_addictive')
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(residual_addictive, label='residual_addictive')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Performing STL(LOESS) decomposition

stl = STL(data['Close'], period=30)
result = stl.fit()

plt.figure(figsize=(15, 10))
plt.subplot(411)
plt.plot(result.observed, label='Original')
plt.legend(loc='upper left')
plt.subplot(412)
plt.plot(result.trend, label='trend_addictive')
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(result.seasonal, label='seasonal_addictive')
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(result.resid, label='residual_addictive')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
def check_stationary(data):
    adf_test = adfuller(data)
    print("ADF Statistics: ", adf_test[0])
    print("P value: ", adf_test[1])
    if(adf_test[1] < 0.05):
        print("Data is stationary")
    else:
        print("Data is not stationary. Differencing required.")

# %%
check_stationary(data['Close'])
# Out:
# ADF Statistics:  -1.0507513734372762
# P value:  0.734307091629161
# Data is not stationary. Differencing required.

# %%
data['Close_diff'] = data['Close'].diff()
data.dropna(inplace=True)

check_stationary(data['Close_diff'])
# Out:
# ADF Statistics:  -14.296983283626867
# P value:  1.2476035300232849e-26
# Data is stationary

# %%
# Split data
train_size = int(len(data) * 0.7)
train = data['Close'][:train_size]
test = data['Close'][train_size:]

# %%
test.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 124 entries, 2024-05-23 to 2024-11-19
# Series name: Close
# Non-Null Count  Dtype
# --------------  -----
# 124 non-null    float64
# dtypes: float64(1)
# memory usage: 1.9 KB

# %%
# ACF Plot
plt.figure(figsize=(12,6))
plt.subplot(1,2, 1)
plot_acf(data['Close'].diff().diff().dropna(), ax=plt.gca(), lags=50)
plt.title('ACF')
# PACF Plot
plt.subplot(1,2, 2)
plot_pacf(data['Close'].diff().diff().dropna(), ax=plt.gca(), lags=50, method='ywm')
plt.title('PACF')

plt.tight_layout()
plt.show()

# %%
model = ARIMA(train, order=(2,2,7))
model_fit = model.fit()

# %%
predictions = model_fit.predict(start=len(train), end=len(train) + len(test) - 1, dynamic=False)

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label="Actual Close Price", color='blue', linewidth=2)
plt.plot(test.index, predictions, label="Predicted Close Price", color='orange', linestyle='dashed', linewidth=2)
plt.title("Actual vs Predicted Close Price")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Use Auto ARIMA to find the best parameters
print("Running Auto ARIMA...")
auto_model = auto_arima(
    train,
    seasonal=True,           # Set to True for SARIMA
    m=5,                    # Frequency of seasonality (e.g., 12 for monthly)
    trace=True,              # Enables output of parameter tuning progress
    error_action='ignore',   # Silences warnings on invalid combinations
    suppress_warnings=True,  # Suppresses convergence warnings
    stepwise=True,           # Faster search
    max_order=20             # Limits the sum of (p+q) for ARIMA
)

# Summary of the best model
print("Best Model Summary:")
print(auto_model.summary())

# Forecast on the test data
forecast = auto_model.predict(n_periods=len(test))
# Out:
# Running Auto ARIMA...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[5] intercept   : AIC=759.309, Time=1.37 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=765.918, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=759.753, Time=0.42 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=758.305, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=769.948, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[5] intercept   : AIC=756.694, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[5] intercept   : AIC=758.375, Time=0.12 sec
#  ARIMA(0,1,1)(1,0,1)[5] intercept   : AIC=755.475, Time=0.28 sec
#  ARIMA(0,1,1)(2,0,1)[5] intercept   : AIC=756.710, Time=0.49 sec
#  ARIMA(0,1,1)(1,0,2)[5] intercept   : AIC=756.701, Time=0.44 sec
#  ARIMA(0,1,1)(0,0,2)[5] intercept   : AIC=757.734, Time=0.20 sec
#  ARIMA(0,1,1)(2,0,0)[5] intercept   : AIC=758.202, Time=0.22 sec
#  ARIMA(0,1,1)(2,0,2)[5] intercept   : AIC=758.701, Time=0.77 sec
#  ARIMA(0,1,0)(1,0,1)[5] intercept   : AIC=766.445, Time=0.29 sec
#  ARIMA(1,1,1)(1,0,1)[5] intercept   : AIC=757.446, Time=0.45 sec
#  ARIMA(0,1,2)(1,0,1)[5] intercept   : AIC=757.424, Time=0.53 sec
#  ARIMA(1,1,0)(1,0,1)[5] intercept   : AIC=756.868, Time=0.29 sec
#  ARIMA(1,1,2)(1,0,1)[5] intercept   : AIC=757.271, Time=0.97 sec
#  ARIMA(0,1,1)(1,0,1)[5]             : AIC=757.457, Time=0.21 sec
#
# Best model:  ARIMA(0,1,1)(1,0,1)[5] intercept
# Total fit time: 7.397 seconds
# Best Model Summary:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  289
# Model:             SARIMAX(0, 1, 1)x(1, 0, 1, 5)   Log Likelihood                -372.737
# Date:                           Wed, 11 Dec 2024   AIC                            755.475
# Time:                                   01:56:16   BIC                            773.790
# Sample:                                        0   HQIC                           762.814
#                                            - 289
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.2362      0.119      1.981      0.048       0.003       0.470
# ma.L1          0.2203      0.046      4.798      0.000       0.130       0.310
# ar.S.L5       -0.7628      0.153     -4.972      0.000      -1.064      -0.462
# ma.S.L5        0.8514      0.128      6.642      0.000       0.600       1.103
# sigma2         0.7782      0.066     11.764      0.000       0.649       0.908
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.02
# Prob(Q):                              0.97   Prob(JB):                         0.99
# Heteroskedasticity (H):               4.55   Skew:                             0.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Evaluate
mse = mean_squared_error(test, forecast)
mae = mean_absolute_error(test, forecast)
mape = (np.abs((test - forecast) / test).mean()) * 100

print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label="Actual Close Price", color='blue', linewidth=2)
plt.plot(test.index, forecast, label="Predicted Close Price", color='orange', linestyle='dashed', linewidth=2)
plt.title("Actual vs Predicted Close Price")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 208.5311
# MAE: 11.4007
# MAPE: nan%
