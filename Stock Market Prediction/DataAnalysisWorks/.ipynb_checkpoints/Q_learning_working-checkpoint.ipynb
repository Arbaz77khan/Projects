# %%
import pandas as pd 
import numpy as np 
import random

data = pd.read_csv('D:\Master_Folder\Data Science Course\Projects\StockMarket\stock_data/SUZLON.NS_2023-01-01_to_2024-11-21_ML.csv')

class MarketEnvironment:
    def __init__(self, data):
        self.data = data.reset_index()
        self.current_step = 0
        self.done = False

    def reset(self):
        self.current_step = 0
        self.done = False

        return self.data.iloc[self.current_step][['Cluster', 'Anomaly']].values

    def step(self, action):

        current_close = self.data['Close'].iloc[self.current_step]
        next_close = self.data['Close'].iloc[self.current_step + 1] if self.current_step + 1 < len(self.data) else current_close

        if action == 0:
            reward = next_close - current_close
        elif action == 1: 
            reward = current_close - next_close
        elif action == 2:
            reward = -0.01

        self.current_step +=1
        if self.current_step >=len(self.data) - 1:
            self.done = True

        next_state = (self.data.iloc[self.current_step][['Cluster', 'Anomaly']].values if not self.done else None)

        return next_state, reward, self.done

class QLearningAgent:
    def __init__(self, state_size, action_size, learning_rate=0.5, discount_factor=0.1, exploration_rate=1.0, exploration_decay=0.999999999): 
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_rate = exploration_rate
        self.exploration_decay = exploration_decay
        self.q_table = {}

    def get_q_values(self, state):
        state_tuple = tuple(state)
        if state_tuple not in self.q_table:
            self.q_table[state_tuple] = np.zeros(self.action_size)
        return self.q_table[state_tuple]

    def choose_action(self, state):
        if np.random.rand() < self.exploration_rate:
            return np.random.choice(self.action_size)
        q_values = self.get_q_values(state)
        return np.argmax(q_values)

    def learn(self, state, action, reward, next_state): 
        state_tuple = tuple(state)
        next_state_tuple = tuple(next_state) if next_state is not None else None

        q_values = self.get_q_values(state)
        q_next = np.max(self.get_q_values(next_state)) if next_state_tuple else 0

        q_values[action] += self.learning_rate * (reward + self.discount_factor * q_next - q_values[action])

        self.exploration_rate *= self.exploration_decay

        # print(f"Exploration Rate after decay: {self.exploration_rate}")
        

def train_rl(data, episodes=1000):
    
    env = MarketEnvironment(data)
    agent = QLearningAgent(state_size=2, action_size=3)

    rewards_per_episode = []

    # print("pt 1")

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        # print("pt 2")
        while not env.done:
            action = agent.choose_action(state)
            next_state, reward, done = env.step(action)
            agent.learn(state, action, reward, next_state)

            state = next_state
            total_reward += reward

        rewards_per_episode.append(total_reward)

        if (episode + 1) % 100 == 0:
            print(f"Episode {episode}, Total Reward: {total_reward:.2f}, Exploration Rate: {agent.exploration_rate:.4f}")
        # print((pd.DataFrame(agent.q_table)).T)
        # print("----------------------------------------------------------------------------------------------------------")

    return agent, rewards_per_episode

trained_agent, rewards = train_rl(data)
# Out:
# Exploration Rate after decay: 0.999999999
# Exploration Rate after decay: 0.9999999980000001
# Exploration Rate after decay: 0.9999999970000001
# Exploration Rate after decay: 0.9999999960000001
# Exploration Rate after decay: 0.9999999950000001
# Exploration Rate after decay: 0.9999999940000002
# Exploration Rate after decay: 0.9999999930000002
# Exploration Rate after decay: 0.9999999920000002
# Exploration Rate after decay: 0.9999999910000003
# Exploration Rate after decay: 0.9999999900000003
# Exploration Rate after decay: 0.9999999890000003
# Exploration Rate after decay: 0.9999999880000003
# Exploration Rate after decay: 0.9999999870000004
# Exploration Rate after decay: 0.9999999860000004
# Exploration Rate after decay: 0.9999999850000004
# Exploration Rate after decay: 0.9999999840000005
# Exploration Rate after decay: 0.9999999830000005
# Exploration Rate after decay: 0.9999999820000005
# Exploration Rate after decay: 0.9999999810000005
# Exploration Rate after decay: 0.9999999800000006
# Exploration Rate after decay: 0.9999999790000006
# Exploration Rate after decay: 0.9999999780000006
# Exploration Rate after decay: 0.9999999770000007
# Exploration Rate after decay: 0.9999999760000007
# Exploration Rate after decay: 0.9999999750000007
# Exploration Rate after decay: 0.9999999740000007
# Exploration Rate after decay: 0.9999999730000008
# Exploration Rate after decay: 0.9999999720000008
# Exploration Rate after decay: 0.9999999710000008
# Exploration Rate after decay: 0.9999999700000008
# Exploration Rate after decay: 0.9999999690000009
# Exploration Rate after decay: 0.9999999680000009
# Exploration Rate after decay: 0.9999999670000009
# Exploration Rate after decay: 0.999999966000001
# Exploration Rate after decay: 0.999999965000001
# Exploration Rate after decay: 0.999999964000001
# Exploration Rate after decay: 0.999999963000001
# Exploration Rate after decay: 0.9999999620000011
# Exploration Rate after decay: 0.9999999610000011
# Exploration Rate after decay: 0.9999999600000011
# Exploration Rate after decay: 0.9999999590000012
# Exploration Rate after decay: 0.9999999580000012
# Exploration Rate after decay: 0.9999999570000012
# Exploration Rate after decay: 0.9999999560000012
# Exploration Rate after decay: 0.9999999550000013
# Exploration Rate after decay: 0.9999999540000013
# Exploration Rate after decay: 0.9999999530000013
# Exploration Rate after decay: 0.9999999520000014
# Exploration Rate after decay: 0.9999999510000014
# Exploration Rate after decay: 0.9999999500000014
# Exploration Rate after decay: 0.9999999490000014
# Exploration Rate after decay: 0.9999999480000015
# Exploration Rate after decay: 0.9999999470000015
# Exploration Rate after decay: 0.9999999460000015
# Exploration Rate after decay: 0.9999999450000016
# Exploration Rate after decay: 0.9999999440000016
# Exploration Rate after decay: 0.9999999430000017
# Exploration Rate after decay: 0.9999999420000019
# Exploration Rate after decay: 0.999999941000002
# Exploration Rate after decay: 0.9999999400000021
# Exploration Rate after decay: 0.9999999390000023
# Exploration Rate after decay: 0.9999999380000024
# Exploration Rate after decay: 0.9999999370000026
# Exploration Rate after decay: 0.9999999360000027
# Exploration Rate after decay: 0.9999999350000028
# Exploration Rate after decay: 0.999999934000003
# Exploration Rate after decay: 0.9999999330000031
# Exploration Rate after decay: 0.9999999320000033
# Exploration Rate after decay: 0.9999999310000034
# Exploration Rate after decay: 0.9999999300000035
# Exploration Rate after decay: 0.9999999290000037
# Exploration Rate after decay: 0.9999999280000038
# Exploration Rate after decay: 0.999999927000004
# Exploration Rate after decay: 0.9999999260000041
# Exploration Rate after decay: 0.9999999250000042
# Exploration Rate after decay: 0.9999999240000044
# Exploration Rate after decay: 0.9999999230000045
# Exploration Rate after decay: 0.9999999220000046
# Exploration Rate after decay: 0.9999999210000048
# Exploration Rate after decay: 0.9999999200000049
# Exploration Rate after decay: 0.9999999190000051
# Exploration Rate after decay: 0.9999999180000052
# Exploration Rate after decay: 0.9999999170000053
# Exploration Rate after decay: 0.9999999160000055
# Exploration Rate after decay: 0.9999999150000056
# Exploration Rate after decay: 0.9999999140000058
# Exploration Rate after decay: 0.9999999130000059
# Exploration Rate after decay: 0.999999912000006
# Exploration Rate after decay: 0.9999999110000062
# Exploration Rate after decay: 0.9999999100000063
# Exploration Rate after decay: 0.9999999090000065
# Exploration Rate after decay: 0.9999999080000066
# Exploration Rate after decay: 0.9999999070000067
# Exploration Rate after decay: 0.9999999060000069
# Exploration Rate after decay: 0.999999905000007
# Exploration Rate after decay: 0.9999999040000072
# Exploration Rate after decay: 0.9999999030000073
# Exploration Rate after decay: 0.9999999020000074
# Exploration Rate after decay: 0.9999999010000076
# Exploration Rate after decay: 0.9999999000000077
# Exploration Rate after decay: 0.9999998990000079
# Exploration Rate after decay: 0.999999898000008
# Exploration Rate after decay: 0.9999998970000081
# Exploration Rate after decay: 0.9999998960000083
# Exploration Rate after decay: 0.9999998950000084
# Exploration Rate after decay: 0.9999998940000085
# Exploration Rate after decay: 0.9999998930000087
# Exploration Rate after decay: 0.9999998920000088
# Exploration Rate after decay: 0.999999891000009
# Exploration Rate after decay: 0.9999998900000091
# Exploration Rate after decay: 0.9999998890000092
# Exploration Rate after decay: 0.9999998880000094
# Exploration Rate after decay: 0.9999998870000095
# Exploration Rate after decay: 0.9999998860000097
# Exploration Rate after decay: 0.9999998850000098
# Exploration Rate after decay: 0.9999998840000099
# Exploration Rate after decay: 0.9999998830000101
# Exploration Rate after decay: 0.9999998820000102
# Exploration Rate after decay: 0.9999998810000104
# Exploration Rate after decay: 0.9999998800000105
# Exploration Rate after decay: 0.9999998790000106
# Exploration Rate after decay: 0.9999998780000108
# Exploration Rate after decay: 0.9999998770000109
# Exploration Rate after decay: 0.9999998760000111
# Exploration Rate after decay: 0.9999998750000112
# Exploration Rate after decay: 0.9999998740000113
# Exploration Rate after decay: 0.9999998730000115
# Exploration Rate after decay: 0.9999998720000116
# Exploration Rate after decay: 0.9999998710000118
# Exploration Rate after decay: 0.9999998700000119
# Exploration Rate after decay: 0.999999869000012
# Exploration Rate after decay: 0.9999998680000122
# Exploration Rate after decay: 0.9999998670000123
# Exploration Rate after decay: 0.9999998660000124
# Exploration Rate after decay: 0.9999998650000126
# Exploration Rate after decay: 0.9999998640000127
# Exploration Rate after decay: 0.9999998630000129
# Exploration Rate after decay: 0.999999862000013
# Exploration Rate after decay: 0.9999998610000131
# Exploration Rate after decay: 0.9999998600000133
# Exploration Rate after decay: 0.9999998590000134
# Exploration Rate after decay: 0.9999998580000136
# Exploration Rate after decay: 0.9999998570000137
# Exploration Rate after decay: 0.9999998560000138
# Exploration Rate after decay: 0.999999855000014
# Exploration Rate after decay: 0.9999998540000141
# Exploration Rate after decay: 0.9999998530000143
# Exploration Rate after decay: 0.9999998520000144
# Exploration Rate after decay: 0.9999998510000145
# Exploration Rate after decay: 0.9999998500000147
# Exploration Rate after decay: 0.9999998490000148
# Exploration Rate after decay: 0.999999848000015
# Exploration Rate after decay: 0.9999998470000151
# Exploration Rate after decay: 0.9999998460000152
# Exploration Rate after decay: 0.9999998450000154
# Exploration Rate after decay: 0.9999998440000155
# Exploration Rate after decay: 0.9999998430000157
# Exploration Rate after decay: 0.9999998420000158
# Exploration Rate after decay: 0.9999998410000159
# Exploration Rate after decay: 0.9999998400000161
# Exploration Rate after decay: 0.9999998390000162
# Exploration Rate after decay: 0.9999998380000164
# Exploration Rate after decay: 0.9999998370000165
# Exploration Rate after decay: 0.9999998360000166
# Exploration Rate after decay: 0.9999998350000168
# Exploration Rate after decay: 0.9999998340000169
# Exploration Rate after decay: 0.999999833000017
# Exploration Rate after decay: 0.9999998320000173
# Exploration Rate after decay: 0.9999998310000175
# Exploration Rate after decay: 0.9999998300000178
# Exploration Rate after decay: 0.999999829000018
# Exploration Rate after decay: 0.9999998280000183
# Exploration Rate after decay: 0.9999998270000185
# Exploration Rate after decay: 0.9999998260000188
# Exploration Rate after decay: 0.999999825000019
# Exploration Rate after decay: 0.9999998240000193
# Exploration Rate after decay: 0.9999998230000195
# Exploration Rate after decay: 0.9999998220000198
# Exploration Rate after decay: 0.99999982100002
# Exploration Rate after decay: 0.9999998200000203
# Exploration Rate after decay: 0.9999998190000206
# Exploration Rate after decay: 0.9999998180000208
# Exploration Rate after decay: 0.999999817000021
# Exploration Rate after decay: 0.9999998160000213
# Exploration Rate after decay: 0.9999998150000216
# Exploration Rate after decay: 0.9999998140000218
# Exploration Rate after decay: 0.999999813000022
# Exploration Rate after decay: 0.9999998120000223
# Exploration Rate after decay: 0.9999998110000226
# Exploration Rate after decay: 0.9999998100000228
# Exploration Rate after decay: 0.999999809000023
# Exploration Rate after decay: 0.9999998080000233
# Exploration Rate after decay: 0.9999998070000236
# Exploration Rate after decay: 0.9999998060000238
# Exploration Rate after decay: 0.9999998050000241
# Exploration Rate after decay: 0.9999998040000243
# Exploration Rate after decay: 0.9999998030000246
# Exploration Rate after decay: 0.9999998020000248
# Exploration Rate after decay: 0.9999998010000251
# Exploration Rate after decay: 0.9999998000000253
# Exploration Rate after decay: 0.9999997990000256
# Exploration Rate after decay: 0.9999997980000258
# Exploration Rate after decay: 0.9999997970000261
# Exploration Rate after decay: 0.9999997960000263
# Exploration Rate after decay: 0.9999997950000266
# Exploration Rate after decay: 0.9999997940000268
# Exploration Rate after decay: 0.9999997930000271
# Exploration Rate after decay: 0.9999997920000273
# Exploration Rate after decay: 0.9999997910000276
# Exploration Rate after decay: 0.9999997900000278
# Exploration Rate after decay: 0.9999997890000281
# Exploration Rate after decay: 0.9999997880000283
# Exploration Rate after decay: 0.9999997870000286
# Exploration Rate after decay: 0.9999997860000288
# Exploration Rate after decay: 0.9999997850000291
# Exploration Rate after decay: 0.9999997840000293
# Exploration Rate after decay: 0.9999997830000296
# Exploration Rate after decay: 0.9999997820000298
# Exploration Rate after decay: 0.9999997810000301
# Exploration Rate after decay: 0.9999997800000303
# Exploration Rate after decay: 0.9999997790000306
# Exploration Rate after decay: 0.9999997780000308
# Exploration Rate after decay: 0.9999997770000311
# Exploration Rate after decay: 0.9999997760000313
# Exploration Rate after decay: 0.9999997750000316
# Exploration Rate after decay: 0.9999997740000318
# Exploration Rate after decay: 0.9999997730000321
# Exploration Rate after decay: 0.9999997720000323
# Exploration Rate after decay: 0.9999997710000326
# Exploration Rate after decay: 0.9999997700000328
# Exploration Rate after decay: 0.9999997690000331
# Exploration Rate after decay: 0.9999997680000333
# Exploration Rate after decay: 0.9999997670000336
# Exploration Rate after decay: 0.9999997660000338
# Exploration Rate after decay: 0.9999997650000341
# Exploration Rate after decay: 0.9999997640000343
# Exploration Rate after decay: 0.9999997630000346
# Exploration Rate after decay: 0.9999997620000348
# Exploration Rate after decay: 0.9999997610000351
# Exploration Rate after decay: 0.9999997600000353
# Exploration Rate after decay: 0.9999997590000356
# Exploration Rate after decay: 0.9999997580000358
# Exploration Rate after decay: 0.9999997570000361
# Exploration Rate after decay: 0.9999997560000363
# Exploration Rate after decay: 0.9999997550000366
# Exploration Rate after decay: 0.9999997540000368
# Exploration Rate after decay: 0.9999997530000371
# Exploration Rate after decay: 0.9999997520000373
# Exploration Rate after decay: 0.9999997510000376
# Exploration Rate after decay: 0.9999997500000378
# Exploration Rate after decay: 0.9999997490000381
# Exploration Rate after decay: 0.9999997480000383
# Exploration Rate after decay: 0.9999997470000386
# Exploration Rate after decay: 0.9999997460000388
# Exploration Rate after decay: 0.9999997450000391
# Exploration Rate after decay: 0.9999997440000393
# Exploration Rate after decay: 0.9999997430000396
# Exploration Rate after decay: 0.9999997420000398
# Exploration Rate after decay: 0.9999997410000401
# Exploration Rate after decay: 0.9999997400000403
# Exploration Rate after decay: 0.9999997390000406
# Exploration Rate after decay: 0.9999997380000408
# Exploration Rate after decay: 0.9999997370000411
# Exploration Rate after decay: 0.9999997360000413
# Exploration Rate after decay: 0.9999997350000416
# Exploration Rate after decay: 0.9999997340000418
# Exploration Rate after decay: 0.9999997330000421
# Exploration Rate after decay: 0.9999997320000423
# Exploration Rate after decay: 0.9999997310000426
# Exploration Rate after decay: 0.9999997300000428
# Exploration Rate after decay: 0.9999997290000431
# Exploration Rate after decay: 0.9999997280000433
# Exploration Rate after decay: 0.9999997270000436
# Exploration Rate after decay: 0.9999997260000438
# Exploration Rate after decay: 0.9999997250000441
# Exploration Rate after decay: 0.9999997240000443
# Exploration Rate after decay: 0.9999997230000446
# Exploration Rate after decay: 0.9999997220000448
# Exploration Rate after decay: 0.9999997210000452
# Exploration Rate after decay: 0.9999997200000456
# Exploration Rate after decay: 0.9999997190000459
# Exploration Rate after decay: 0.9999997180000463
# Exploration Rate after decay: 0.9999997170000466
# Exploration Rate after decay: 0.999999716000047
# Exploration Rate after decay: 0.9999997150000474
# Exploration Rate after decay: 0.9999997140000477
# Exploration Rate after decay: 0.9999997130000481
# Exploration Rate after decay: 0.9999997120000484
# Exploration Rate after decay: 0.9999997110000488
# Exploration Rate after decay: 0.9999997100000492
# Exploration Rate after decay: 0.9999997090000495
# Exploration Rate after decay: 0.9999997080000499
# Exploration Rate after decay: 0.9999997070000503
# Exploration Rate after decay: 0.9999997060000506
# Exploration Rate after decay: 0.999999705000051
# Exploration Rate after decay: 0.9999997040000513
# Exploration Rate after decay: 0.9999997030000517
# Exploration Rate after decay: 0.9999997020000521
# Exploration Rate after decay: 0.9999997010000524
# Exploration Rate after decay: 0.9999997000000528
# Exploration Rate after decay: 0.9999996990000531
# Exploration Rate after decay: 0.9999996980000535
# Exploration Rate after decay: 0.9999996970000539
# Exploration Rate after decay: 0.9999996960000542
# Exploration Rate after decay: 0.9999996950000546
# Exploration Rate after decay: 0.999999694000055
# Exploration Rate after decay: 0.9999996930000553
# Exploration Rate after decay: 0.9999996920000557
# Exploration Rate after decay: 0.999999691000056
# Exploration Rate after decay: 0.9999996900000564
# Exploration Rate after decay: 0.9999996890000568
# Exploration Rate after decay: 0.9999996880000571
# Exploration Rate after decay: 0.9999996870000575
# Exploration Rate after decay: 0.9999996860000578
# Exploration Rate after decay: 0.9999996850000582
# Exploration Rate after decay: 0.9999996840000586
# Exploration Rate after decay: 0.9999996830000589
# Exploration Rate after decay: 0.9999996820000593
# Exploration Rate after decay: 0.9999996810000596
# Exploration Rate after decay: 0.99999968000006
# Exploration Rate after decay: 0.9999996790000604
# Exploration Rate after decay: 0.9999996780000607
# Exploration Rate after decay: 0.9999996770000611
# Exploration Rate after decay: 0.9999996760000615
# Exploration Rate after decay: 0.9999996750000618
# Exploration Rate after decay: 0.9999996740000622
# Exploration Rate after decay: 0.9999996730000625
# Exploration Rate after decay: 0.9999996720000629
# Exploration Rate after decay: 0.9999996710000633
# Exploration Rate after decay: 0.9999996700000636
# Exploration Rate after decay: 0.999999669000064
# Exploration Rate after decay: 0.9999996680000643
# Exploration Rate after decay: 0.9999996670000647
# Exploration Rate after decay: 0.9999996660000651
# Exploration Rate after decay: 0.9999996650000654
# Exploration Rate after decay: 0.9999996640000658
# Exploration Rate after decay: 0.9999996630000662
# Exploration Rate after decay: 0.9999996620000665
# Exploration Rate after decay: 0.9999996610000669
# Exploration Rate after decay: 0.9999996600000672
# Exploration Rate after decay: 0.9999996590000676
# Exploration Rate after decay: 0.999999658000068
# Exploration Rate after decay: 0.9999996570000683
# Exploration Rate after decay: 0.9999996560000687
# Exploration Rate after decay: 0.999999655000069
# Exploration Rate after decay: 0.9999996540000694
# Exploration Rate after decay: 0.9999996530000698
# Exploration Rate after decay: 0.9999996520000701
# Exploration Rate after decay: 0.9999996510000705
# Exploration Rate after decay: 0.9999996500000708
# Exploration Rate after decay: 0.9999996490000712
# Exploration Rate after decay: 0.9999996480000716
# Exploration Rate after decay: 0.9999996470000719
# Exploration Rate after decay: 0.9999996460000723
# Exploration Rate after decay: 0.9999996450000727
# Exploration Rate after decay: 0.999999644000073
# Exploration Rate after decay: 0.9999996430000734
# Exploration Rate after decay: 0.9999996420000737
# Exploration Rate after decay: 0.9999996410000741
# Exploration Rate after decay: 0.9999996400000745
# Exploration Rate after decay: 0.9999996390000748
# Exploration Rate after decay: 0.9999996380000752
# Exploration Rate after decay: 0.9999996370000755
# Exploration Rate after decay: 0.9999996360000759
# Exploration Rate after decay: 0.9999996350000763
# Exploration Rate after decay: 0.9999996340000766
# Exploration Rate after decay: 0.999999633000077
# Exploration Rate after decay: 0.9999996320000774
# Exploration Rate after decay: 0.9999996310000777
# Exploration Rate after decay: 0.9999996300000781
# Exploration Rate after decay: 0.9999996290000784
# Exploration Rate after decay: 0.9999996280000788
# Exploration Rate after decay: 0.9999996270000792
# Exploration Rate after decay: 0.9999996260000795
# Exploration Rate after decay: 0.9999996250000799
# Exploration Rate after decay: 0.9999996240000802
# Exploration Rate after decay: 0.9999996230000806
# Exploration Rate after decay: 0.999999622000081
# Exploration Rate after decay: 0.9999996210000813
# Exploration Rate after decay: 0.9999996200000817
# Exploration Rate after decay: 0.999999619000082
# Exploration Rate after decay: 0.9999996180000824
# Exploration Rate after decay: 0.9999996170000828
# Exploration Rate after decay: 0.9999996160000831
# Exploration Rate after decay: 0.9999996150000835
# Exploration Rate after decay: 0.9999996140000839
# Exploration Rate after decay: 0.9999996130000842
# Exploration Rate after decay: 0.9999996120000846
# Exploration Rate after decay: 0.9999996110000849
# Exploration Rate after decay: 0.9999996100000854
# Exploration Rate after decay: 0.9999996090000859
# Exploration Rate after decay: 0.9999996080000864
# Exploration Rate after decay: 0.9999996070000868
# Exploration Rate after decay: 0.9999996060000873
# Exploration Rate after decay: 0.9999996050000878
# Exploration Rate after decay: 0.9999996040000882
# Exploration Rate after decay: 0.9999996030000887
# Exploration Rate after decay: 0.9999996020000892
# Exploration Rate after decay: 0.9999996010000897
# Exploration Rate after decay: 0.9999996000000901
# Exploration Rate after decay: 0.9999995990000906
# Exploration Rate after decay: 0.9999995980000911
# Exploration Rate after decay: 0.9999995970000916
# Exploration Rate after decay: 0.999999596000092
# Exploration Rate after decay: 0.9999995950000925
# Exploration Rate after decay: 0.999999594000093
# Exploration Rate after decay: 0.9999995930000934
# Exploration Rate after decay: 0.9999995920000939
# Exploration Rate after decay: 0.9999995910000944
# Exploration Rate after decay: 0.9999995900000949
# Exploration Rate after decay: 0.9999995890000953
# Exploration Rate after decay: 0.9999995880000958
# Exploration Rate after decay: 0.9999995870000963
# Exploration Rate after decay: 0.9999995860000968
# Exploration Rate after decay: 0.9999995850000972
# Exploration Rate after decay: 0.9999995840000977
# Exploration Rate after decay: 0.9999995830000982
# Exploration Rate after decay: 0.9999995820000986
# Exploration Rate after decay: 0.9999995810000991
# Exploration Rate after decay: 0.9999995800000996
# Exploration Rate after decay: 0.9999995790001001
# Exploration Rate after decay: 0.9999995780001005
# Exploration Rate after decay: 0.999999577000101
# Exploration Rate after decay: 0.9999995760001015
# Exploration Rate after decay: 0.999999575000102
# Exploration Rate after decay: 0.9999995740001024
# Exploration Rate after decay: 0.9999995730001029
# Exploration Rate after decay: 0.9999995720001034
# Exploration Rate after decay: 0.9999995710001038
# Exploration Rate after decay: 0.9999995700001043
# Exploration Rate after decay: 0.9999995690001048
# Exploration Rate after decay: 0.9999995680001053
# Exploration Rate after decay: 0.9999995670001057
# Exploration Rate after decay: 0.9999995660001062
# Exploration Rate after decay: 0.9999995650001067
# Exploration Rate after decay: 0.9999995640001071
# Exploration Rate after decay: 0.9999995630001076
# Exploration Rate after decay: 0.9999995620001081
# Exploration Rate after decay: 0.9999995610001086
# Exploration Rate after decay: 0.999999560000109
# Exploration Rate after decay: 0.9999995590001095
# Exploration Rate after decay: 0.99999955800011
# Exploration Rate after decay: 0.9999995570001105
# Exploration Rate after decay: 0.9999995560001109
# Exploration Rate after decay: 0.9999995550001114
# Exploration Rate after decay: 0.9999995540001119
# Exploration Rate after decay: 0.9999995530001123
# Exploration Rate after decay: 0.9999995520001128
# Exploration Rate after decay: 0.9999995510001133
# Exploration Rate after decay: 0.9999995500001138
# Exploration Rate after decay: 0.9999995490001142
# Exploration Rate after decay: 0.9999995480001147
# Exploration Rate after decay: 0.9999995470001152
# Exploration Rate after decay: 0.9999995460001156
# Exploration Rate after decay: 0.9999995450001161
# Exploration Rate after decay: 0.9999995440001166
# Exploration Rate after decay: 0.9999995430001171
# Exploration Rate after decay: 0.9999995420001175
# Exploration Rate after decay: 0.999999541000118
# Exploration Rate after decay: 0.9999995400001185
# Exploration Rate after decay: 0.999999539000119
# Exploration Rate after decay: 0.9999995380001194
# Exploration Rate after decay: 0.9999995370001199
# Exploration Rate after decay: 0.9999995360001204
# Exploration Rate after decay: 0.9999995350001208
# Exploration Rate after decay: 0.9999995340001213
# Exploration Rate after decay: 0.9999995330001218
# Exploration Rate after decay: 0.9999995320001223
# Exploration Rate after decay: 0.9999995310001227
# Exploration Rate after decay: 0.9999995300001232
# Exploration Rate after decay: 0.9999995290001237
# Exploration Rate after decay: 0.9999995280001241
# Exploration Rate after decay: 0.9999995270001246
# Exploration Rate after decay: 0.9999995260001251
# Exploration Rate after decay: 0.9999995250001256
# Exploration Rate after decay: 0.999999524000126
# Exploration Rate after decay: 0.9999995230001265
# Exploration Rate after decay: 0.999999522000127
# Exploration Rate after decay: 0.9999995210001275
# Exploration Rate after decay: 0.9999995200001279
# Exploration Rate after decay: 0.9999995190001284
# Exploration Rate after decay: 0.9999995180001289
# Exploration Rate after decay: 0.9999995170001293
# Exploration Rate after decay: 0.9999995160001298
# Exploration Rate after decay: 0.9999995150001303
# Exploration Rate after decay: 0.9999995140001308
# Exploration Rate after decay: 0.9999995130001312
# Exploration Rate after decay: 0.9999995120001317
# Exploration Rate after decay: 0.9999995110001322
# Exploration Rate after decay: 0.9999995100001327
# Exploration Rate after decay: 0.9999995090001331
# Exploration Rate after decay: 0.9999995080001336
# Exploration Rate after decay: 0.9999995070001341
# Exploration Rate after decay: 0.9999995060001345
# Exploration Rate after decay: 0.999999505000135
# Exploration Rate after decay: 0.9999995040001355
# Exploration Rate after decay: 0.999999503000136
# Exploration Rate after decay: 0.9999995020001364
# Exploration Rate after decay: 0.9999995010001369
# Exploration Rate after decay: 0.9999995000001374
# Exploration Rate after decay: 0.999999499000138
# Exploration Rate after decay: 0.9999994980001385
# Exploration Rate after decay: 0.9999994970001391
# Exploration Rate after decay: 0.9999994960001397
# Exploration Rate after decay: 0.9999994950001403
# Exploration Rate after decay: 0.9999994940001409
# Exploration Rate after decay: 0.9999994930001415
# Exploration Rate after decay: 0.999999492000142
# Exploration Rate after decay: 0.9999994910001426
# Exploration Rate after decay: 0.9999994900001432
# Exploration Rate after decay: 0.9999994890001438
# Exploration Rate after decay: 0.9999994880001444
# Exploration Rate after decay: 0.999999487000145
# Exploration Rate after decay: 0.9999994860001455
# Exploration Rate after decay: 0.9999994850001461
# Exploration Rate after decay: 0.9999994840001467
# Exploration Rate after decay: 0.9999994830001473
# Exploration Rate after decay: 0.9999994820001479
# Exploration Rate after decay: 0.9999994810001485
# Exploration Rate after decay: 0.999999480000149
# Exploration Rate after decay: 0.9999994790001496
# Exploration Rate after decay: 0.9999994780001502
# Exploration Rate after decay: 0.9999994770001508
# Exploration Rate after decay: 0.9999994760001514
# Exploration Rate after decay: 0.999999475000152
# Exploration Rate after decay: 0.9999994740001525
# Exploration Rate after decay: 0.9999994730001531
# Exploration Rate after decay: 0.9999994720001537
# Exploration Rate after decay: 0.9999994710001543
# Exploration Rate after decay: 0.9999994700001549
# Exploration Rate after decay: 0.9999994690001555
# Exploration Rate after decay: 0.999999468000156
# Exploration Rate after decay: 0.9999994670001566
# Exploration Rate after decay: 0.9999994660001572
# Exploration Rate after decay: 0.9999994650001578
# Exploration Rate after decay: 0.9999994640001584
# Exploration Rate after decay: 0.999999463000159
# Exploration Rate after decay: 0.9999994620001595
# Exploration Rate after decay: 0.9999994610001601
# Exploration Rate after decay: 0.9999994600001607
# Exploration Rate after decay: 0.9999994590001613
# Exploration Rate after decay: 0.9999994580001619
# Exploration Rate after decay: 0.9999994570001625
# Exploration Rate after decay: 0.999999456000163
# Exploration Rate after decay: 0.9999994550001636
# Exploration Rate after decay: 0.9999994540001642
# Exploration Rate after decay: 0.9999994530001648
# Exploration Rate after decay: 0.9999994520001654
# Exploration Rate after decay: 0.999999451000166
# Exploration Rate after decay: 0.9999994500001665
# Exploration Rate after decay: 0.9999994490001671
# Exploration Rate after decay: 0.9999994480001677
# Exploration Rate after decay: 0.9999994470001683
# Exploration Rate after decay: 0.9999994460001689
# Exploration Rate after decay: 0.9999994450001695
# Exploration Rate after decay: 0.99999944400017
# Exploration Rate after decay: 0.9999994430001706
# Exploration Rate after decay: 0.9999994420001712
# Exploration Rate after decay: 0.9999994410001718
# Exploration Rate after decay: 0.9999994400001724
# Exploration Rate after decay: 0.999999439000173
# Exploration Rate after decay: 0.9999994380001735
# Exploration Rate after decay: 0.9999994370001741
# Exploration Rate after decay: 0.9999994360001747
# Exploration Rate after decay: 0.9999994350001753
# Exploration Rate after decay: 0.9999994340001759
# Exploration Rate after decay: 0.9999994330001765
# Exploration Rate after decay: 0.999999432000177
# Exploration Rate after decay: 0.9999994310001776
# Exploration Rate after decay: 0.9999994300001782
# Exploration Rate after decay: 0.9999994290001788
# Exploration Rate after decay: 0.9999994280001794
# Exploration Rate after decay: 0.99999942700018
# Exploration Rate after decay: 0.9999994260001805
# Exploration Rate after decay: 0.9999994250001811
# Exploration Rate after decay: 0.9999994240001817
# Exploration Rate after decay: 0.9999994230001823
# Exploration Rate after decay: 0.9999994220001829
# Exploration Rate after decay: 0.9999994210001835
# Exploration Rate after decay: 0.999999420000184
# Exploration Rate after decay: 0.9999994190001846
# Exploration Rate after decay: 0.9999994180001852
# Exploration Rate after decay: 0.9999994170001858
# Exploration Rate after decay: 0.9999994160001864
# Exploration Rate after decay: 0.999999415000187
# Exploration Rate after decay: 0.9999994140001875
# Exploration Rate after decay: 0.9999994130001881
# Exploration Rate after decay: 0.9999994120001887
# Exploration Rate after decay: 0.9999994110001893
# Exploration Rate after decay: 0.9999994100001899
# Exploration Rate after decay: 0.9999994090001905
# Exploration Rate after decay: 0.999999408000191
# Exploration Rate after decay: 0.9999994070001916
# Exploration Rate after decay: 0.9999994060001922
# Exploration Rate after decay: 0.9999994050001928
# Exploration Rate after decay: 0.9999994040001934
# Exploration Rate after decay: 0.999999403000194
# Exploration Rate after decay: 0.9999994020001945
# Exploration Rate after decay: 0.9999994010001951
# Exploration Rate after decay: 0.9999994000001957
# Exploration Rate after decay: 0.9999993990001963
# Exploration Rate after decay: 0.9999993980001969
# Exploration Rate after decay: 0.9999993970001975
# Exploration Rate after decay: 0.999999396000198
# Exploration Rate after decay: 0.9999993950001986
# Exploration Rate after decay: 0.9999993940001992
# Exploration Rate after decay: 0.9999993930001998
# Exploration Rate after decay: 0.9999993920002004
# Exploration Rate after decay: 0.999999391000201
# Exploration Rate after decay: 0.9999993900002015
# Exploration Rate after decay: 0.9999993890002021
# Exploration Rate after decay: 0.9999993880002028
# Exploration Rate after decay: 0.9999993870002035
# Exploration Rate after decay: 0.9999993860002042
# Exploration Rate after decay: 0.9999993850002049
# Exploration Rate after decay: 0.9999993840002056
# Exploration Rate after decay: 0.9999993830002063
# Exploration Rate after decay: 0.999999382000207
# Exploration Rate after decay: 0.9999993810002077
# Exploration Rate after decay: 0.9999993800002084
# Exploration Rate after decay: 0.9999993790002091
# Exploration Rate after decay: 0.9999993780002098
# Exploration Rate after decay: 0.9999993770002105
# Exploration Rate after decay: 0.9999993760002112
# Exploration Rate after decay: 0.9999993750002119
# Exploration Rate after decay: 0.9999993740002125
# Exploration Rate after decay: 0.9999993730002132
# Exploration Rate after decay: 0.9999993720002139
# Exploration Rate after decay: 0.9999993710002146
# Exploration Rate after decay: 0.9999993700002153
# Exploration Rate after decay: 0.999999369000216
# Exploration Rate after decay: 0.9999993680002167
# Exploration Rate after decay: 0.9999993670002174
# Exploration Rate after decay: 0.9999993660002181
# Exploration Rate after decay: 0.9999993650002188
# Exploration Rate after decay: 0.9999993640002195
# Exploration Rate after decay: 0.9999993630002202
# Exploration Rate after decay: 0.9999993620002209
# Exploration Rate after decay: 0.9999993610002216
# Exploration Rate after decay: 0.9999993600002223
# Exploration Rate after decay: 0.999999359000223
# Exploration Rate after decay: 0.9999993580002237
# Exploration Rate after decay: 0.9999993570002244
# Exploration Rate after decay: 0.999999356000225
# Exploration Rate after decay: 0.9999993550002257
# Exploration Rate after decay: 0.9999993540002264
# Exploration Rate after decay: 0.9999993530002271
# Exploration Rate after decay: 0.9999993520002278
# Exploration Rate after decay: 0.9999993510002285
# Exploration Rate after decay: 0.9999993500002292
# Exploration Rate after decay: 0.9999993490002299
# Exploration Rate after decay: 0.9999993480002306
# Exploration Rate after decay: 0.9999993470002313
# Exploration Rate after decay: 0.999999346000232
# Exploration Rate after decay: 0.9999993450002327
# Exploration Rate after decay: 0.9999993440002334
# Exploration Rate after decay: 0.9999993430002341
# Exploration Rate after decay: 0.9999993420002348
# Exploration Rate after decay: 0.9999993410002355
# Exploration Rate after decay: 0.9999993400002362
# Exploration Rate after decay: 0.9999993390002369
# Exploration Rate after decay: 0.9999993380002375
# Exploration Rate after decay: 0.9999993370002382
# Exploration Rate after decay: 0.9999993360002389
# Exploration Rate after decay: 0.9999993350002396
# Exploration Rate after decay: 0.9999993340002403
# Exploration Rate after decay: 0.999999333000241
# Exploration Rate after decay: 0.9999993320002417
# Exploration Rate after decay: 0.9999993310002424
# Exploration Rate after decay: 0.9999993300002431
# Exploration Rate after decay: 0.9999993290002438
# Exploration Rate after decay: 0.9999993280002445
# Exploration Rate after decay: 0.9999993270002452
# Exploration Rate after decay: 0.9999993260002459
# Exploration Rate after decay: 0.9999993250002466
# Exploration Rate after decay: 0.9999993240002473
# Exploration Rate after decay: 0.999999323000248
# Exploration Rate after decay: 0.9999993220002487
# Exploration Rate after decay: 0.9999993210002494
# Exploration Rate after decay: 0.99999932000025
# Exploration Rate after decay: 0.9999993190002507
# Exploration Rate after decay: 0.9999993180002514
# Exploration Rate after decay: 0.9999993170002521
# Exploration Rate after decay: 0.9999993160002528
# Exploration Rate after decay: 0.9999993150002535
# Exploration Rate after decay: 0.9999993140002542
# Exploration Rate after decay: 0.9999993130002549
# Exploration Rate after decay: 0.9999993120002556
# Exploration Rate after decay: 0.9999993110002563
# Exploration Rate after decay: 0.999999310000257
# Exploration Rate after decay: 0.9999993090002577
# Exploration Rate after decay: 0.9999993080002584
# Exploration Rate after decay: 0.9999993070002591
# Exploration Rate after decay: 0.9999993060002598
# Exploration Rate after decay: 0.9999993050002605
# Exploration Rate after decay: 0.9999993040002612
# Exploration Rate after decay: 0.9999993030002619
# Exploration Rate after decay: 0.9999993020002625
# Exploration Rate after decay: 0.9999993010002632
# Exploration Rate after decay: 0.9999993000002639
# Exploration Rate after decay: 0.9999992990002646
# Exploration Rate after decay: 0.9999992980002653
# Exploration Rate after decay: 0.999999297000266
# Exploration Rate after decay: 0.9999992960002667
# Exploration Rate after decay: 0.9999992950002674
# Exploration Rate after decay: 0.9999992940002681
# Exploration Rate after decay: 0.9999992930002688
# Exploration Rate after decay: 0.9999992920002695
# Exploration Rate after decay: 0.9999992910002702
# Exploration Rate after decay: 0.9999992900002709
# Exploration Rate after decay: 0.9999992890002716
# Exploration Rate after decay: 0.9999992880002723
# Exploration Rate after decay: 0.999999287000273
# Exploration Rate after decay: 0.9999992860002737
# Exploration Rate after decay: 0.9999992850002744
# Exploration Rate after decay: 0.999999284000275
# Exploration Rate after decay: 0.9999992830002757
# Exploration Rate after decay: 0.9999992820002764
# Exploration Rate after decay: 0.9999992810002771
# Exploration Rate after decay: 0.9999992800002778
# Exploration Rate after decay: 0.9999992790002785
# Exploration Rate after decay: 0.9999992780002792
# Exploration Rate after decay: 0.99999927700028
# Exploration Rate after decay: 0.9999992760002808
# Exploration Rate after decay: 0.9999992750002816
# Exploration Rate after decay: 0.9999992740002824
# Exploration Rate after decay: 0.9999992730002832
# Exploration Rate after decay: 0.999999272000284
# Exploration Rate after decay: 0.9999992710002849
# Exploration Rate after decay: 0.9999992700002857
# Exploration Rate after decay: 0.9999992690002865
# Exploration Rate after decay: 0.9999992680002873
# Exploration Rate after decay: 0.9999992670002881
# Exploration Rate after decay: 0.9999992660002889
# Exploration Rate after decay: 0.9999992650002897
# Exploration Rate after decay: 0.9999992640002905
# Exploration Rate after decay: 0.9999992630002913
# Exploration Rate after decay: 0.9999992620002921
# Exploration Rate after decay: 0.9999992610002929
# Exploration Rate after decay: 0.9999992600002937
# Exploration Rate after decay: 0.9999992590002945
# Exploration Rate after decay: 0.9999992580002953
# Exploration Rate after decay: 0.9999992570002961
# Exploration Rate after decay: 0.9999992560002969
# Exploration Rate after decay: 0.9999992550002977
# Exploration Rate after decay: 0.9999992540002985
# Exploration Rate after decay: 0.9999992530002993
# Exploration Rate after decay: 0.9999992520003002
# Exploration Rate after decay: 0.999999251000301
# Exploration Rate after decay: 0.9999992500003018
# Exploration Rate after decay: 0.9999992490003026
# Exploration Rate after decay: 0.9999992480003034
# Exploration Rate after decay: 0.9999992470003042
# Exploration Rate after decay: 0.999999246000305
# Exploration Rate after decay: 0.9999992450003058
# Exploration Rate after decay: 0.9999992440003066
# Exploration Rate after decay: 0.9999992430003074
# Exploration Rate after decay: 0.9999992420003082
# Exploration Rate after decay: 0.999999241000309
# Exploration Rate after decay: 0.9999992400003098
# Exploration Rate after decay: 0.9999992390003106
# Exploration Rate after decay: 0.9999992380003114
# Exploration Rate after decay: 0.9999992370003122
# Exploration Rate after decay: 0.999999236000313
# Exploration Rate after decay: 0.9999992350003138
# Exploration Rate after decay: 0.9999992340003147
# Exploration Rate after decay: 0.9999992330003155
# Exploration Rate after decay: 0.9999992320003163
# Exploration Rate after decay: 0.9999992310003171
# Exploration Rate after decay: 0.9999992300003179
# Exploration Rate after decay: 0.9999992290003187
# Exploration Rate after decay: 0.9999992280003195
# Exploration Rate after decay: 0.9999992270003203
# Exploration Rate after decay: 0.9999992260003211
# Exploration Rate after decay: 0.9999992250003219
# Exploration Rate after decay: 0.9999992240003227
# Exploration Rate after decay: 0.9999992230003235
# Exploration Rate after decay: 0.9999992220003243
# Exploration Rate after decay: 0.9999992210003251
# Exploration Rate after decay: 0.9999992200003259
# Exploration Rate after decay: 0.9999992190003267
# Exploration Rate after decay: 0.9999992180003275
# Exploration Rate after decay: 0.9999992170003283
# Exploration Rate after decay: 0.9999992160003291
# Exploration Rate after decay: 0.99999921500033
# Exploration Rate after decay: 0.9999992140003308
# Exploration Rate after decay: 0.9999992130003316
# Exploration Rate after decay: 0.9999992120003324
# Exploration Rate after decay: 0.9999992110003332
# Exploration Rate after decay: 0.999999210000334
# Exploration Rate after decay: 0.9999992090003348
# Exploration Rate after decay: 0.9999992080003356
# Exploration Rate after decay: 0.9999992070003364
# Exploration Rate after decay: 0.9999992060003372
# Exploration Rate after decay: 0.999999205000338
# Exploration Rate after decay: 0.9999992040003388
# Exploration Rate after decay: 0.9999992030003396
# Exploration Rate after decay: 0.9999992020003404
# Exploration Rate after decay: 0.9999992010003412
# Exploration Rate after decay: 0.999999200000342
# Exploration Rate after decay: 0.9999991990003428
# Exploration Rate after decay: 0.9999991980003436
# Exploration Rate after decay: 0.9999991970003445
# Exploration Rate after decay: 0.9999991960003453
# Exploration Rate after decay: 0.9999991950003461
# Exploration Rate after decay: 0.9999991940003469
# Exploration Rate after decay: 0.9999991930003477
# Exploration Rate after decay: 0.9999991920003485
# Exploration Rate after decay: 0.9999991910003493
# Exploration Rate after decay: 0.9999991900003501
# Exploration Rate after decay: 0.9999991890003509
# Exploration Rate after decay: 0.9999991880003517
# Exploration Rate after decay: 0.9999991870003525
# Exploration Rate after decay: 0.9999991860003533
# Exploration Rate after decay: 0.9999991850003541
# Exploration Rate after decay: 0.9999991840003549
# Exploration Rate after decay: 0.9999991830003557
# Exploration Rate after decay: 0.9999991820003565
# Exploration Rate after decay: 0.9999991810003573
# Exploration Rate after decay: 0.9999991800003581
# Exploration Rate after decay: 0.999999179000359
# Exploration Rate after decay: 0.9999991780003598
# Exploration Rate after decay: 0.9999991770003606
# Exploration Rate after decay: 0.9999991760003614
# Exploration Rate after decay: 0.9999991750003622
# Exploration Rate after decay: 0.999999174000363
# Exploration Rate after decay: 0.9999991730003638
# Exploration Rate after decay: 0.9999991720003646
# Exploration Rate after decay: 0.9999991710003654
# Exploration Rate after decay: 0.9999991700003662
# Exploration Rate after decay: 0.999999169000367
# Exploration Rate after decay: 0.9999991680003678
# Exploration Rate after decay: 0.9999991670003686
# Exploration Rate after decay: 0.9999991660003695
# Exploration Rate after decay: 0.9999991650003704
# Exploration Rate after decay: 0.9999991640003714
# Exploration Rate after decay: 0.9999991630003723
# Exploration Rate after decay: 0.9999991620003732
# Exploration Rate after decay: 0.9999991610003741
# Exploration Rate after decay: 0.999999160000375
# Exploration Rate after decay: 0.999999159000376
# Exploration Rate after decay: 0.9999991580003769
# Exploration Rate after decay: 0.9999991570003778
# Exploration Rate after decay: 0.9999991560003787
# Exploration Rate after decay: 0.9999991550003796
# Exploration Rate after decay: 0.9999991540003805
# Exploration Rate after decay: 0.9999991530003814
# Exploration Rate after decay: 0.9999991520003824
# Exploration Rate after decay: 0.9999991510003833
# Exploration Rate after decay: 0.9999991500003842
# Exploration Rate after decay: 0.9999991490003851
# Exploration Rate after decay: 0.999999148000386
# Exploration Rate after decay: 0.999999147000387
# Exploration Rate after decay: 0.9999991460003879
# Exploration Rate after decay: 0.9999991450003888
# Exploration Rate after decay: 0.9999991440003897
# Exploration Rate after decay: 0.9999991430003906
# Exploration Rate after decay: 0.9999991420003915
# Exploration Rate after decay: 0.9999991410003924
# Exploration Rate after decay: 0.9999991400003934
# Exploration Rate after decay: 0.9999991390003943
# Exploration Rate after decay: 0.9999991380003952
# Exploration Rate after decay: 0.9999991370003961
# Exploration Rate after decay: 0.999999136000397
# Exploration Rate after decay: 0.9999991350003979
# Exploration Rate after decay: 0.9999991340003989
# Exploration Rate after decay: 0.9999991330003998
# Exploration Rate after decay: 0.9999991320004007
# Exploration Rate after decay: 0.9999991310004016
# Exploration Rate after decay: 0.9999991300004025
# Exploration Rate after decay: 0.9999991290004034
# Exploration Rate after decay: 0.9999991280004044
# Exploration Rate after decay: 0.9999991270004053
# Exploration Rate after decay: 0.9999991260004062
# Exploration Rate after decay: 0.9999991250004071
# Exploration Rate after decay: 0.999999124000408
# Exploration Rate after decay: 0.9999991230004089
# Exploration Rate after decay: 0.9999991220004099
# Exploration Rate after decay: 0.9999991210004108
# Exploration Rate after decay: 0.9999991200004117
# Exploration Rate after decay: 0.9999991190004126
# Exploration Rate after decay: 0.9999991180004135
# Exploration Rate after decay: 0.9999991170004144
# Exploration Rate after decay: 0.9999991160004154
# Exploration Rate after decay: 0.9999991150004163
# Exploration Rate after decay: 0.9999991140004172
# Exploration Rate after decay: 0.9999991130004181
# Exploration Rate after decay: 0.999999112000419
# Exploration Rate after decay: 0.9999991110004199
# Exploration Rate after decay: 0.9999991100004209
# Exploration Rate after decay: 0.9999991090004218
# Exploration Rate after decay: 0.9999991080004227
# Exploration Rate after decay: 0.9999991070004236
# Exploration Rate after decay: 0.9999991060004245
# Exploration Rate after decay: 0.9999991050004254
# Exploration Rate after decay: 0.9999991040004264
# Exploration Rate after decay: 0.9999991030004273
# Exploration Rate after decay: 0.9999991020004282
# Exploration Rate after decay: 0.9999991010004291
# Exploration Rate after decay: 0.99999910000043
# Exploration Rate after decay: 0.9999990990004309
# Exploration Rate after decay: 0.9999990980004319
# Exploration Rate after decay: 0.9999990970004328
# Exploration Rate after decay: 0.9999990960004337
# Exploration Rate after decay: 0.9999990950004346
# Exploration Rate after decay: 0.9999990940004355
# Exploration Rate after decay: 0.9999990930004364
# Exploration Rate after decay: 0.9999990920004374
# Exploration Rate after decay: 0.9999990910004383
# Exploration Rate after decay: 0.9999990900004392
# Exploration Rate after decay: 0.9999990890004401
# Exploration Rate after decay: 0.999999088000441
# Exploration Rate after decay: 0.9999990870004419
# Exploration Rate after decay: 0.9999990860004428
# Exploration Rate after decay: 0.9999990850004438
# Exploration Rate after decay: 0.9999990840004447
# Exploration Rate after decay: 0.9999990830004456
# Exploration Rate after decay: 0.9999990820004465
# Exploration Rate after decay: 0.9999990810004474
# Exploration Rate after decay: 0.9999990800004483
# Exploration Rate after decay: 0.9999990790004493
# Exploration Rate after decay: 0.9999990780004502
# Exploration Rate after decay: 0.9999990770004511
# Exploration Rate after decay: 0.999999076000452
# Exploration Rate after decay: 0.9999990750004529
# Exploration Rate after decay: 0.9999990740004538
# Exploration Rate after decay: 0.9999990730004548
# Exploration Rate after decay: 0.9999990720004557
# Exploration Rate after decay: 0.9999990710004566
# Exploration Rate after decay: 0.9999990700004575
# Exploration Rate after decay: 0.9999990690004584
# Exploration Rate after decay: 0.9999990680004593
# Exploration Rate after decay: 0.9999990670004603
# Exploration Rate after decay: 0.9999990660004612
# Exploration Rate after decay: 0.9999990650004621
# Exploration Rate after decay: 0.999999064000463
# Exploration Rate after decay: 0.9999990630004639
# Exploration Rate after decay: 0.9999990620004648
# Exploration Rate after decay: 0.9999990610004658
# Exploration Rate after decay: 0.9999990600004667
# Exploration Rate after decay: 0.9999990590004676
# Exploration Rate after decay: 0.9999990580004685
# Exploration Rate after decay: 0.9999990570004694
# Exploration Rate after decay: 0.9999990560004703
# Exploration Rate after decay: 0.9999990550004714
# Exploration Rate after decay: 0.9999990540004724
# Exploration Rate after decay: 0.9999990530004734
# Exploration Rate after decay: 0.9999990520004745
# Exploration Rate after decay: 0.9999990510004755
# Exploration Rate after decay: 0.9999990500004765
# Exploration Rate after decay: 0.9999990490004775
# Exploration Rate after decay: 0.9999990480004786
# Exploration Rate after decay: 0.9999990470004796
# Exploration Rate after decay: 0.9999990460004806
# Exploration Rate after decay: 0.9999990450004816
# Exploration Rate after decay: 0.9999990440004827
# Exploration Rate after decay: 0.9999990430004837
# Exploration Rate after decay: 0.9999990420004847
# Exploration Rate after decay: 0.9999990410004858
# Exploration Rate after decay: 0.9999990400004868
# Exploration Rate after decay: 0.9999990390004878
# Exploration Rate after decay: 0.9999990380004888
# Exploration Rate after decay: 0.9999990370004899
# Exploration Rate after decay: 0.9999990360004909
# Exploration Rate after decay: 0.9999990350004919
# Exploration Rate after decay: 0.999999034000493
# Exploration Rate after decay: 0.999999033000494
# Exploration Rate after decay: 0.999999032000495
# Exploration Rate after decay: 0.999999031000496
# Exploration Rate after decay: 0.9999990300004971
# Exploration Rate after decay: 0.9999990290004981
# Exploration Rate after decay: 0.9999990280004991
# Exploration Rate after decay: 0.9999990270005001
# Exploration Rate after decay: 0.9999990260005012
# Exploration Rate after decay: 0.9999990250005022
# Exploration Rate after decay: 0.9999990240005032
# Exploration Rate after decay: 0.9999990230005043
# Exploration Rate after decay: 0.9999990220005053
# Exploration Rate after decay: 0.9999990210005063
# Exploration Rate after decay: 0.9999990200005073
# Exploration Rate after decay: 0.9999990190005084
# Exploration Rate after decay: 0.9999990180005094
# ...
# Exploration Rate after decay: 0.9999801331978996
# Exploration Rate after decay: 0.9999801321979195
# Exploration Rate after decay: 0.9999801311979394
# Exploration Rate after decay: 0.9999801301979593
# Exploration Rate after decay: 0.9999801291979792
# Exploration Rate after decay: 0.9999801281979991
# Exploration Rate after decay: 0.999980127198019
# Exploration Rate after decay: 0.9999801261980389
# Exploration Rate after decay: 0.9999801251980588
# Exploration Rate after decay: 0.9999801241980787
# Exploration Rate after decay: 0.9999801231980986
# Exploration Rate after decay: 0.9999801221981185
# Exploration Rate after decay: 0.9999801211981384
# Exploration Rate after decay: 0.9999801201981583
# Exploration Rate after decay: 0.9999801191981782
# Exploration Rate after decay: 0.9999801181981981
# Exploration Rate after decay: 0.999980117198218
# Exploration Rate after decay: 0.9999801161982379
# Exploration Rate after decay: 0.9999801151982578
# Exploration Rate after decay: 0.9999801141982777
# Exploration Rate after decay: 0.9999801131982976
# Exploration Rate after decay: 0.9999801121983175
# Exploration Rate after decay: 0.9999801111983374
# Exploration Rate after decay: 0.9999801101983573
# Exploration Rate after decay: 0.9999801091983772
# Exploration Rate after decay: 0.9999801081983971
# Exploration Rate after decay: 0.999980107198417
# Exploration Rate after decay: 0.9999801061984369
# Exploration Rate after decay: 0.9999801051984568
# Exploration Rate after decay: 0.9999801041984767
# Exploration Rate after decay: 0.9999801031984966
# Exploration Rate after decay: 0.9999801021985165
# Exploration Rate after decay: 0.9999801011985364
# Exploration Rate after decay: 0.9999801001985563
# Exploration Rate after decay: 0.9999800991985762
# Exploration Rate after decay: 0.9999800981985961
# Exploration Rate after decay: 0.999980097198616
# Exploration Rate after decay: 0.9999800961986359
# Exploration Rate after decay: 0.9999800951986558
# Exploration Rate after decay: 0.9999800941986757
# Exploration Rate after decay: 0.9999800931986956
# Exploration Rate after decay: 0.9999800921987155
# Exploration Rate after decay: 0.9999800911987354
# Exploration Rate after decay: 0.9999800901987553
# Exploration Rate after decay: 0.9999800891987752
# Exploration Rate after decay: 0.9999800881987951
# Exploration Rate after decay: 0.999980087198815
# Exploration Rate after decay: 0.9999800861988349
# Exploration Rate after decay: 0.9999800851988548
# Exploration Rate after decay: 0.9999800841988747
# Exploration Rate after decay: 0.9999800831988946
# Exploration Rate after decay: 0.9999800821989145
# Exploration Rate after decay: 0.9999800811989344
# Exploration Rate after decay: 0.9999800801989543
# Exploration Rate after decay: 0.9999800791989742
# Exploration Rate after decay: 0.9999800781989941
# Exploration Rate after decay: 0.999980077199014
# Exploration Rate after decay: 0.999980076199034
# Exploration Rate after decay: 0.9999800751990539
# Exploration Rate after decay: 0.9999800741990738
# Exploration Rate after decay: 0.9999800731990937
# Exploration Rate after decay: 0.9999800721991136
# Exploration Rate after decay: 0.9999800711991335
# Exploration Rate after decay: 0.9999800701991535
# Exploration Rate after decay: 0.9999800691991735
# Exploration Rate after decay: 0.9999800681991935
# Exploration Rate after decay: 0.9999800671992135
# Exploration Rate after decay: 0.9999800661992335
# Exploration Rate after decay: 0.9999800651992535
# Exploration Rate after decay: 0.9999800641992735
# Exploration Rate after decay: 0.9999800631992936
# Exploration Rate after decay: 0.9999800621993136
# Exploration Rate after decay: 0.9999800611993336
# Exploration Rate after decay: 0.9999800601993536
# Exploration Rate after decay: 0.9999800591993736
# Exploration Rate after decay: 0.9999800581993936
# Exploration Rate after decay: 0.9999800571994136
# Exploration Rate after decay: 0.9999800561994336
# Exploration Rate after decay: 0.9999800551994537
# Exploration Rate after decay: 0.9999800541994737
# Exploration Rate after decay: 0.9999800531994937
# Exploration Rate after decay: 0.9999800521995137
# Exploration Rate after decay: 0.9999800511995337
# Exploration Rate after decay: 0.9999800501995537
# Exploration Rate after decay: 0.9999800491995737
# Exploration Rate after decay: 0.9999800481995937
# Exploration Rate after decay: 0.9999800471996138
# Exploration Rate after decay: 0.9999800461996338
# Exploration Rate after decay: 0.9999800451996538
# Exploration Rate after decay: 0.9999800441996738
# Exploration Rate after decay: 0.9999800431996938
# Exploration Rate after decay: 0.9999800421997138
# Exploration Rate after decay: 0.9999800411997338
# Exploration Rate after decay: 0.9999800401997538
# Exploration Rate after decay: 0.9999800391997739
# Exploration Rate after decay: 0.9999800381997939
# Exploration Rate after decay: 0.9999800371998139
# Exploration Rate after decay: 0.9999800361998339
# Exploration Rate after decay: 0.9999800351998539
# Exploration Rate after decay: 0.9999800341998739
# Exploration Rate after decay: 0.9999800331998939
# Exploration Rate after decay: 0.9999800321999139
# Exploration Rate after decay: 0.999980031199934
# Exploration Rate after decay: 0.999980030199954
# Exploration Rate after decay: 0.999980029199974
# Exploration Rate after decay: 0.999980028199994
# Exploration Rate after decay: 0.999980027200014
# Exploration Rate after decay: 0.999980026200034
# Exploration Rate after decay: 0.999980025200054
# Exploration Rate after decay: 0.999980024200074
# Exploration Rate after decay: 0.999980023200094
# Exploration Rate after decay: 0.9999800222001141
# Exploration Rate after decay: 0.9999800212001341
# Exploration Rate after decay: 0.9999800202001541
# Exploration Rate after decay: 0.9999800192001741
# Exploration Rate after decay: 0.9999800182001941
# Exploration Rate after decay: 0.9999800172002141
# Exploration Rate after decay: 0.9999800162002341
# Exploration Rate after decay: 0.9999800152002541
# Exploration Rate after decay: 0.9999800142002742
# Exploration Rate after decay: 0.9999800132002942
# Exploration Rate after decay: 0.9999800122003142
# Exploration Rate after decay: 0.9999800112003342
# Exploration Rate after decay: 0.9999800102003542
# Exploration Rate after decay: 0.9999800092003742
# Exploration Rate after decay: 0.9999800082003942
# Exploration Rate after decay: 0.9999800072004142
# Exploration Rate after decay: 0.9999800062004343
# Exploration Rate after decay: 0.9999800052004543
# Exploration Rate after decay: 0.9999800042004743
# Exploration Rate after decay: 0.9999800032004943
# Exploration Rate after decay: 0.9999800022005143
# Exploration Rate after decay: 0.9999800012005343
# Exploration Rate after decay: 0.9999800002005543
# Exploration Rate after decay: 0.9999799992005743
# Exploration Rate after decay: 0.9999799982005944
# Exploration Rate after decay: 0.9999799972006144
# Exploration Rate after decay: 0.9999799962006344
# Exploration Rate after decay: 0.9999799952006544
# Exploration Rate after decay: 0.9999799942006744
# Exploration Rate after decay: 0.9999799932006944
# Exploration Rate after decay: 0.9999799922007144
# Exploration Rate after decay: 0.9999799912007344
# Exploration Rate after decay: 0.9999799902007545
# Exploration Rate after decay: 0.9999799892007745
# Exploration Rate after decay: 0.9999799882007945
# Exploration Rate after decay: 0.9999799872008145
# Exploration Rate after decay: 0.9999799862008345
# Exploration Rate after decay: 0.9999799852008545
# Exploration Rate after decay: 0.9999799842008745
# Exploration Rate after decay: 0.9999799832008945
# Exploration Rate after decay: 0.9999799822009146
# Exploration Rate after decay: 0.9999799812009346
# Exploration Rate after decay: 0.9999799802009546
# Exploration Rate after decay: 0.9999799792009746
# Exploration Rate after decay: 0.9999799782009946
# Exploration Rate after decay: 0.9999799772010146
# Exploration Rate after decay: 0.9999799762010346
# Exploration Rate after decay: 0.9999799752010546
# Exploration Rate after decay: 0.9999799742010747
# Exploration Rate after decay: 0.9999799732010947
# Exploration Rate after decay: 0.9999799722011147
# Exploration Rate after decay: 0.9999799712011347
# Exploration Rate after decay: 0.9999799702011547
# Exploration Rate after decay: 0.9999799692011747
# Exploration Rate after decay: 0.9999799682011947
# Exploration Rate after decay: 0.9999799672012147
# Exploration Rate after decay: 0.9999799662012347
# Exploration Rate after decay: 0.9999799652012548
# Exploration Rate after decay: 0.9999799642012748
# Exploration Rate after decay: 0.9999799632012948
# Exploration Rate after decay: 0.9999799622013148
# Exploration Rate after decay: 0.9999799612013348
# Exploration Rate after decay: 0.9999799602013548
# Exploration Rate after decay: 0.999979959201375
# Exploration Rate after decay: 0.9999799582013951
# Exploration Rate after decay: 0.9999799572014152
# Exploration Rate after decay: 0.9999799562014353
# Exploration Rate after decay: 0.9999799552014554
# Exploration Rate after decay: 0.9999799542014756
# Exploration Rate after decay: 0.9999799532014957
# Exploration Rate after decay: 0.9999799522015158
# Exploration Rate after decay: 0.9999799512015359
# Exploration Rate after decay: 0.9999799502015561
# Exploration Rate after decay: 0.9999799492015762
# Exploration Rate after decay: 0.9999799482015963
# Exploration Rate after decay: 0.9999799472016164
# Exploration Rate after decay: 0.9999799462016365
# Exploration Rate after decay: 0.9999799452016567
# Exploration Rate after decay: 0.9999799442016768
# Exploration Rate after decay: 0.9999799432016969
# Exploration Rate after decay: 0.999979942201717
# Exploration Rate after decay: 0.9999799412017372
# Exploration Rate after decay: 0.9999799402017573
# Exploration Rate after decay: 0.9999799392017774
# Exploration Rate after decay: 0.9999799382017975
# Exploration Rate after decay: 0.9999799372018177
# Exploration Rate after decay: 0.9999799362018378
# Exploration Rate after decay: 0.9999799352018579
# Exploration Rate after decay: 0.999979934201878
# Exploration Rate after decay: 0.9999799332018982
# Exploration Rate after decay: 0.9999799322019183
# Exploration Rate after decay: 0.9999799312019384
# Exploration Rate after decay: 0.9999799302019585
# Exploration Rate after decay: 0.9999799292019786
# Exploration Rate after decay: 0.9999799282019988
# Exploration Rate after decay: 0.9999799272020189
# Exploration Rate after decay: 0.999979926202039
# Exploration Rate after decay: 0.9999799252020591
# Exploration Rate after decay: 0.9999799242020793
# Exploration Rate after decay: 0.9999799232020994
# Exploration Rate after decay: 0.9999799222021195
# Exploration Rate after decay: 0.9999799212021396
# Exploration Rate after decay: 0.9999799202021598
# Exploration Rate after decay: 0.9999799192021799
# Exploration Rate after decay: 0.9999799182022
# Exploration Rate after decay: 0.9999799172022201
# Exploration Rate after decay: 0.9999799162022402
# Exploration Rate after decay: 0.9999799152022604
# Exploration Rate after decay: 0.9999799142022805
# Exploration Rate after decay: 0.9999799132023006
# Exploration Rate after decay: 0.9999799122023207
# Exploration Rate after decay: 0.9999799112023409
# Exploration Rate after decay: 0.999979910202361
# Exploration Rate after decay: 0.9999799092023811
# Exploration Rate after decay: 0.9999799082024012
# Exploration Rate after decay: 0.9999799072024214
# Exploration Rate after decay: 0.9999799062024415
# Exploration Rate after decay: 0.9999799052024616
# Exploration Rate after decay: 0.9999799042024817
# Exploration Rate after decay: 0.9999799032025019
# Exploration Rate after decay: 0.999979902202522
# Exploration Rate after decay: 0.9999799012025421
# Exploration Rate after decay: 0.9999799002025622
# Exploration Rate after decay: 0.9999798992025823
# Exploration Rate after decay: 0.9999798982026025
# Exploration Rate after decay: 0.9999798972026226
# Exploration Rate after decay: 0.9999798962026427
# Exploration Rate after decay: 0.9999798952026628
# Exploration Rate after decay: 0.999979894202683
# Exploration Rate after decay: 0.9999798932027031
# Exploration Rate after decay: 0.9999798922027232
# Exploration Rate after decay: 0.9999798912027433
# Exploration Rate after decay: 0.9999798902027635
# Exploration Rate after decay: 0.9999798892027836
# Exploration Rate after decay: 0.9999798882028037
# Exploration Rate after decay: 0.9999798872028238
# Exploration Rate after decay: 0.999979886202844
# Exploration Rate after decay: 0.9999798852028641
# Exploration Rate after decay: 0.9999798842028842
# Exploration Rate after decay: 0.9999798832029043
# Exploration Rate after decay: 0.9999798822029244
# Exploration Rate after decay: 0.9999798812029446
# Exploration Rate after decay: 0.9999798802029647
# Exploration Rate after decay: 0.9999798792029848
# Exploration Rate after decay: 0.9999798782030049
# Exploration Rate after decay: 0.9999798772030251
# Exploration Rate after decay: 0.9999798762030452
# Exploration Rate after decay: 0.9999798752030653
# Exploration Rate after decay: 0.9999798742030854
# Exploration Rate after decay: 0.9999798732031056
# Exploration Rate after decay: 0.9999798722031257
# Exploration Rate after decay: 0.9999798712031458
# Exploration Rate after decay: 0.9999798702031659
# Exploration Rate after decay: 0.999979869203186
# Exploration Rate after decay: 0.9999798682032062
# Exploration Rate after decay: 0.9999798672032263
# Exploration Rate after decay: 0.9999798662032464
# Exploration Rate after decay: 0.9999798652032665
# Exploration Rate after decay: 0.9999798642032867
# Exploration Rate after decay: 0.9999798632033068
# Exploration Rate after decay: 0.9999798622033269
# Exploration Rate after decay: 0.999979861203347
# Exploration Rate after decay: 0.9999798602033672
# Exploration Rate after decay: 0.9999798592033873
# Exploration Rate after decay: 0.9999798582034074
# Exploration Rate after decay: 0.9999798572034275
# Exploration Rate after decay: 0.9999798562034476
# Exploration Rate after decay: 0.9999798552034678
# Exploration Rate after decay: 0.9999798542034879
# Exploration Rate after decay: 0.999979853203508
# Exploration Rate after decay: 0.9999798522035281
# Exploration Rate after decay: 0.9999798512035483
# Exploration Rate after decay: 0.9999798502035684
# Exploration Rate after decay: 0.9999798492035885
# Exploration Rate after decay: 0.9999798482036087
# Exploration Rate after decay: 0.999979847203629
# Exploration Rate after decay: 0.9999798462036492
# Exploration Rate after decay: 0.9999798452036694
# Exploration Rate after decay: 0.9999798442036897
# Exploration Rate after decay: 0.9999798432037099
# Exploration Rate after decay: 0.9999798422037302
# Exploration Rate after decay: 0.9999798412037504
# Exploration Rate after decay: 0.9999798402037706
# Exploration Rate after decay: 0.9999798392037909
# Exploration Rate after decay: 0.9999798382038111
# Exploration Rate after decay: 0.9999798372038313
# Exploration Rate after decay: 0.9999798362038516
# Exploration Rate after decay: 0.9999798352038718
# Exploration Rate after decay: 0.999979834203892
# Exploration Rate after decay: 0.9999798332039123
# Exploration Rate after decay: 0.9999798322039325
# Exploration Rate after decay: 0.9999798312039527
# Exploration Rate after decay: 0.999979830203973
# Exploration Rate after decay: 0.9999798292039932
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 105
#     100         # print((pd.DataFrame(agent.q_table)).T)
#     101         # print("----------------------------------------------------------------------------------------------------------")
#     103     return agent, rewards_per_episode
# --> 105 trained_agent, rewards = train_rl(data)
#
# Cell In[13], line 89, in train_rl(data, episodes)
#      87 # print("pt 2")
#      88 while not env.done:
# ---> 89     action = agent.choose_action(state)
#      90     next_state, reward, done = env.step(action)
#      91     agent.learn(state, action, reward, next_state)
#
# Cell In[13], line 57, in QLearningAgent.choose_action(self, state)
#      55 def choose_action(self, state):
#      56     if np.random.rand() < self.exploration_rate:
# ---> 57         return np.random.choice(self.action_size)
#      58     q_values = self.get_q_values(state)
#      59     return np.argmax(q_values)
#
# KeyboardInterrupt:
