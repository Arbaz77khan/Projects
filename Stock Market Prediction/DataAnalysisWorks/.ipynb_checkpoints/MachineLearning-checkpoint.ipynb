# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest

# %%
data = pd.read_csv('D:\Master_Folder\Data Science Course\Projects\StockMarket\stock_data\SUZLON.NS_2023-01-01_to_2024-11-21.csv', usecols=['Date', 'Day', 'Weekday', 'Month', 'Year', 'Adj Close', 'Adj_Close_Lag_1', 'Adj_Close_Lag_2', 'Adj_Close_Lag_3', 'Upward_Downward_Probability'])

# %%
data.head()
# Out:
#          Date  Day  Weekday  Month  Year  Adj Close  Adj_Close_Lag_1  \
# 0  2023-03-17   17        4      3  2023       8.00             7.90
# 1  2023-03-20   20        0      3  2023       7.75             8.00
# 2  2023-03-21   21        1      3  2023       7.80             7.75
# 3  2023-03-22   22        2      3  2023       7.80             7.80
# 4  2023-03-23   23        3      3  2023       7.75             7.80
#
#    Adj_Close_Lag_2  Adj_Close_Lag_3  Upward_Downward_Probability
# 0             7.95             7.95                    -2.639057
# 1             7.90             7.95                    -2.639057
# 2             8.00             7.90                    -2.639057
# 3             7.75             8.00                    -2.639057
# 4             7.80             7.75                    -2.639057

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         411 non-null    object
#  1   Day                          411 non-null    int64
#  2   Weekday                      411 non-null    int64
#  3   Month                        411 non-null    int64
#  4   Year                         411 non-null    int64
#  5   Adj Close                    411 non-null    float64
#  6   Adj_Close_Lag_1              411 non-null    float64
#  7   Adj_Close_Lag_2              411 non-null    float64
#  8   Adj_Close_Lag_3              411 non-null    float64
#  9   Upward_Downward_Probability  411 non-null    float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 32.2+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data.set_index('Date', inplace=True)
# Out:
# C:\Users\Arbaz Khan\AppData\Local\Temp\ipykernel_36404\2675603959.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 411 entries, 2023-03-17 to 2024-11-19
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Day                          411 non-null    int64
#  1   Weekday                      411 non-null    int64
#  2   Month                        411 non-null    int64
#  3   Year                         411 non-null    int64
#  4   Adj Close                    411 non-null    float64
#  5   Adj_Close_Lag_1              411 non-null    float64
#  6   Adj_Close_Lag_2              411 non-null    float64
#  7   Adj_Close_Lag_3              411 non-null    float64
#  8   Upward_Downward_Probability  411 non-null    float64
# dtypes: float64(5), int64(4)
# memory usage: 32.1 KB

# %%
data.head()
# Out:
#             Day  Weekday  Month  Year  Adj Close  Adj_Close_Lag_1  \
# Date
# 2023-03-17   17        4      3  2023       8.00             7.90
# 2023-03-20   20        0      3  2023       7.75             8.00
# 2023-03-21   21        1      3  2023       7.80             7.75
# 2023-03-22   22        2      3  2023       7.80             7.80
# 2023-03-23   23        3      3  2023       7.75             7.80
#
#             Adj_Close_Lag_2  Adj_Close_Lag_3  Upward_Downward_Probability
# Date
# 2023-03-17             7.95             7.95                    -2.639057
# 2023-03-20             7.90             7.95                    -2.639057
# 2023-03-21             8.00             7.90                    -2.639057
# 2023-03-22             7.75             8.00                    -2.639057
# 2023-03-23             7.80             7.75                    -2.639057

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data (assumes 'data' is a DataFrame)
scaled_data = scaler.fit_transform(data)

# Created a new Dataframe with scaled values and retain column names
refined_data = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# %%
refined_data.head()
# Out:
#                  Day   Weekday     Month      Year  Adj Close  \
# Date
# 2023-03-17  0.137797  1.414264 -1.227242 -1.062795  -1.468235
# 2023-03-20  0.478971 -1.428096 -1.227242 -1.062795  -1.479848
# 2023-03-21  0.592695 -0.717506 -1.227242 -1.062795  -1.477526
# 2023-03-22  0.706419 -0.006916 -1.227242 -1.062795  -1.477526
# 2023-03-23  0.820144  0.703674 -1.227242 -1.062795  -1.479848
#
#             Adj_Close_Lag_1  Adj_Close_Lag_2  Adj_Close_Lag_3  \
# Date
# 2023-03-17        -1.464870        -1.454490        -1.446435
# 2023-03-20        -1.460230        -1.456807        -1.446435
# 2023-03-21        -1.471829        -1.452174        -1.448747
# 2023-03-22        -1.469509        -1.463755        -1.444123
# 2023-03-23        -1.469509        -1.461439        -1.455683
#
#             Upward_Downward_Probability
# Date
# 2023-03-17                    -2.520329
# 2023-03-20                    -2.520329
# 2023-03-21                    -2.520329
# 2023-03-22                    -2.520329
# 2023-03-23                    -2.520329

# %%
refined_data.describe()
# Out:
#                 Day       Weekday         Month          Year     Adj Close  \
# count  4.110000e+02  4.110000e+02  4.110000e+02  4.110000e+02  4.110000e+02
# mean   5.942800e-17 -1.836865e-17  8.644072e-17 -5.414647e-14 -6.915258e-17
# std    1.001219e+00  1.001219e+00  1.001219e+00  1.001219e+00  1.001219e+00
# min   -1.681793e+00 -1.428096e+00 -1.881029e+00 -1.062795e+00 -1.512366e+00
# 25%   -8.857221e-01 -7.175057e-01 -9.003486e-01 -1.062795e+00 -9.003279e-01
# 50%    2.407305e-02 -6.915718e-03  8.033146e-02  9.409150e-01  2.051459e-03
# 75%    8.201438e-01  7.036743e-01  7.341182e-01  9.409150e-01  6.133932e-01
# max    1.729939e+00  1.414264e+00  1.714798e+00  9.409150e-01  2.094828e+00
#
#        Adj_Close_Lag_1  Adj_Close_Lag_2  Adj_Close_Lag_3  \
# count     4.110000e+02     4.110000e+02     4.110000e+02
# mean     -6.915258e-17     2.074577e-16     2.074577e-16
# std       1.001219e+00     1.001219e+00     1.001219e+00
# min      -1.504306e+00    -1.496181e+00    -1.488052e+00
# 25%      -8.976874e-01    -8.951393e-01    -8.915391e-01
# 50%       5.860934e-03     1.163487e-02     7.854271e-03
# 75%       5.646923e-01     5.121557e-01     5.044859e-01
# max       2.098289e+00     2.100805e+00     2.102585e+00
#
#        Upward_Downward_Probability
# count                 4.110000e+02
# mean                 -3.457629e-17
# std                   1.001219e+00
# min                  -2.576770e+00
# 25%                  -1.680136e-01
# 50%                   2.836169e-01
# 75%                   7.429380e-01
# max                   1.797537e+00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10)) 
sns.heatmap(refined_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Spliting the data into two groups
group_1 = refined_data[['Day', 'Weekday', 'Month', 'Year']]
group_2 = refined_data[['Adj Close', 'Adj_Close_Lag_1', 'Adj_Close_Lag_2', 'Adj_Close_Lag_3']]

# Apply PCA to group 1
pca_group_1 = PCA(n_components=1)

refined_data['Temporal_Features'] = pca_group_1.fit_transform(group_1)
# group_1_pca = pca_group_1.fit_transform(group_1)
# group_1_pca = pd.DataFrame(group_1_pca, columns=['Temporal_Features'])

# Apply PCA to group 2
pca_group_2 = PCA(n_components=1)

refined_data['Price_Features'] = pca_group_2.fit_transform(group_2)
# group_2_pca = pca_group_2.fit_transform(group_2)
# group_2_pca = pd.DataFrame(group_2_pca, columns=['Price_Features'])

# Combine the PCA results with the remaining features
# pca_data = pd.concat([group_1_pca, group_2_pca, scaled_data[['Upward_Downward_Probability']].reset_index(drop=True)], axis=1)
# pca_data.index = scaled_data.index

refined_data.drop(columns=['Day', 'Weekday', 'Month', 'Year', 'Adj Close', 'Adj_Close_Lag_1', 'Adj_Close_Lag_2', 'Adj_Close_Lag_3'], inplace=True)

print("Explained Variance Ratio (Group 1 Temporal features):", pca_group_1.explained_variance_ratio_)
print("Explained Variance Ratio (Group 2 Price Features):", pca_group_2.explained_variance_ratio_)
print(refined_data.head())
# Out:
# Explained Variance Ratio (Group 1 Temporal features): [0.3282166]
# Explained Variance Ratio (Group 2 Price Features): [0.99749558]
#             Upward_Downward_Probability  Temporal_Features  Price_Features
# Date
# 2023-03-17                    -2.520329          -0.059697       -2.917016
# 2023-03-20                    -2.520329           0.261311       -2.921657
# 2023-03-21                    -2.520329           0.174668       -2.925137
# 2023-03-22                    -2.520329           0.088026       -2.927459
# 2023-03-23                    -2.520329           0.001383       -2.933238

# %%
refined_data.sample(20)
# Out:
#             Upward_Downward_Probability  Temporal_Features  Price_Features
# Date
# 2024-03-14                    -2.576770           1.445478       -0.060557
# 2023-09-14                     0.242011          -1.337692       -1.517226
# 2023-07-26                     0.283617          -0.841209       -1.877616
# 2023-10-11                     0.283617          -1.472403       -1.087353
# 2023-09-05                     1.076654          -1.138845       -1.400148
# 2024-04-08                    -0.779287           1.487705        0.299819
# 2024-01-10                     0.420279           2.000390        0.293172
# 2023-03-27                    -1.325618           0.235749       -2.951812
# 2023-05-15                     0.205647          -0.177744       -2.884575
# 2023-06-09                     0.742938          -0.716454       -2.402391
# 2024-07-03                     0.283617           0.654011        1.267581
# 2024-08-30                    -0.155803           0.160775        3.514456
# 2023-06-27                     0.283617          -0.533213       -2.366536
# 2024-01-09                     0.373183           2.087033        0.180868
# 2023-06-15                     0.742938          -0.655374       -2.280875
# 2023-07-19                     0.056495          -0.815646       -1.993410
# 2024-04-02                    -0.779287           1.426624        0.118223
# 2023-03-20                    -2.520329           0.261311       -2.921657
# 2024-07-15                     0.283617           0.776172        1.418413
# 2023-06-23                     0.242011          -0.767578       -2.363127

# %%
refined_data.describe()
# Out:
#        Upward_Downward_Probability  Temporal_Features  Price_Features
# count                 4.110000e+02       4.110000e+02    4.110000e+02
# mean                 -3.457629e-17      -1.383052e-16   -2.766103e-16
# std                   1.001219e+00       1.147200e+00    1.999928e+00
# min                  -2.576770e+00      -2.161430e+00   -2.969208e+00
# 25%                  -1.680136e-01      -9.067381e-01   -1.795247e+00
# 50%                   2.836169e-01      -5.387021e-02    3.478893e-02
# 75%                   7.429380e-01       9.153315e-01    1.093043e+00
# max                   1.797537e+00       2.199237e+00    4.065909e+00

# %%
plt.figure(figsize=(7, 7)) 
sns.heatmap(refined_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Prepare the data for Anamoly\clustering
features = refined_data[['Temporal_Features', 'Price_Features', 'Upward_Downward_Probability']]

# %%
# Use K-Means with predefined 3 clusters (bullish, bearish, neutral)
kmeans = KMeans(n_clusters=3, random_state=42)
refined_data['Cluster'] = kmeans.fit_predict(features)

# %%
# Anomaly Detection with Isolation Forest
iso_forest = IsolationForest(contamination=0.05, random_state=42)

# Fit the model to the data and predict anomalies (-1 for anomalies, 1 for normal points)
refined_data['Anomaly'] = iso_forest.fit_predict(features)

# %%
refined_data['Anomaly'].value_counts()
# Out:
# Anomaly
#  1    390
# -1     21
# Name: count, dtype: int64

# %%
refined_data.sample(20)
# Out:
#             Upward_Downward_Probability  Temporal_Features  Price_Features  \
# Date
# 2024-01-23                     0.283617           2.035908        0.211885
# 2023-08-17                     0.242011          -1.119991       -1.795276
# 2024-02-20                    -0.155803           1.818207        0.653290
# 2023-12-14                    -0.155803          -2.023663       -0.102297
# 2024-10-04                     0.056495          -0.201593        3.535285
# 2023-08-31                     0.742938          -1.171115       -1.369850
# 2023-12-28                    -0.155803          -2.074787       -0.192558
# 2024-09-17                     1.230494           0.228564        4.029404
# 2024-05-06                    -0.155803           1.266351        0.180522
# 2023-09-25                     0.283617          -1.128889       -1.292363
# 2024-01-15                     0.838170           2.148113        0.422814
# 2024-05-03                    -0.361396           0.945343        0.199096
# 2023-06-13                     0.742938          -0.482088       -2.315449
# 2024-09-20                     0.838170          -0.031364        3.930353
# 2024-10-10                    -1.006409          -0.140513        3.222867
# 2023-08-18                     0.283617          -1.206634       -1.804552
# 2024-10-16                    -1.006409          -0.079432        3.233176
# 2024-09-02                    -0.155803           0.366331        3.428724
# 2023-11-01                     0.283617          -1.664543       -0.744272
# 2024-02-12                     0.283617           1.930411        0.771345
#
#             Cluster  Anomaly
# Date
# 2024-01-23        1        1
# 2023-08-17        2        1
# 2024-02-20        1        1
# 2023-12-14        0        1
# 2024-10-04        1        1
# 2023-08-31        0        1
# 2023-12-28        0        1
# 2024-09-17        1        1
# 2024-05-06        1        1
# 2023-09-25        0        1
# 2024-01-15        1        1
# 2024-05-03        1        1
# 2023-06-13        2        1
# 2024-09-20        1        1
# 2024-10-10        1        1
# 2023-08-18        2        1
# 2024-10-16        1        1
# 2024-09-02        1        1
# 2023-11-01        0        1
# 2024-02-12        1        1

# %%
# Visualize the clusters (using the first two features)
plt.figure(figsize=(8, 5))
for cluster in range(3):  # 3 clusters: bullish, bearish, neutral
    cluster_data = refined_data[refined_data['Cluster'] == cluster]
    plt.scatter(cluster_data['Temporal_Features'], cluster_data['Price_Features'], label=f'Cluster {cluster}')
plt.title('K-Means Clustering (Bullish, Bearish, Neutral)')
plt.xlabel('Temporal_Features')
plt.ylabel('Price_Features')
plt.legend()
plt.grid()
plt.show()

# %%
# Assuming you have clustered the data already
cluster_centers = kmeans.cluster_centers_

# You can inspect the centers of the clusters to understand their nature
print("Cluster Centers (Mean values of each cluster's features):")
print(cluster_centers)

# You can also inspect the data points within each cluster
for cluster in range(3):  # Loop through the 3 clusters
    cluster_data = refined_data[refined_data['Cluster'] == cluster]
    print(f"Cluster {cluster} Statistics:")
    print(cluster_data[['Temporal_Features', 'Price_Features', 'Upward_Downward_Probability']].describe())
# Out:
# Cluster Centers (Mean values of each cluster's features):
# [[-1.57972244 -0.71613157  0.41308597]
#  [ 0.87002886  1.48918681 -0.16045378]
#  [-0.50289872 -2.45846177 -0.0051072 ]]
# Cluster 0 Statistics:
#        Temporal_Features  Price_Features  Upward_Downward_Probability
# count          86.000000       86.000000                    86.000000
# mean           -1.579722       -0.716132                     0.413086
# std             0.305987        0.601989                     0.428356
# min            -2.161430       -1.777898                    -0.168014
# 25%            -1.827108       -1.291479                     0.242011
# 50%            -1.576276       -0.722696                     0.283617
# 75%            -1.352731       -0.121055                     0.742938
# max            -0.997830        0.199190                     1.230494
# Cluster 1 Statistics:
#        Temporal_Features  Price_Features  Upward_Downward_Probability
# count         218.000000      218.000000                   218.000000
# mean            0.870029        1.489187                    -0.160454
# std             0.714545        1.382430                     1.162718
# min            -0.444857       -0.222653                    -2.576770
# 25%             0.263288        0.240468                    -0.779287
# 50%             0.846448        0.884631                     0.283617
# 75%             1.478508        2.756966                     0.723066
# max             2.199237        4.065909                     1.230494
# Cluster 2 Statistics:
#        Temporal_Features  Price_Features  Upward_Downward_Probability
# count         107.000000      107.000000                   107.000000
# mean           -0.502899       -2.458462                    -0.005107
# std             0.365282        0.435436                     0.878183
# min            -1.206634       -2.969208                    -2.520329
# 25%            -0.791612       -2.895002                    -0.693095
# 50%            -0.507650       -2.517048                     0.242011
# 75%            -0.214790       -2.002107                     0.537345
# max             0.261311       -1.585429                     1.797537
